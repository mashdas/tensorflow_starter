# %%
import numpy as np
from PIL import Image
def image_to_csv(name):
  img=Image.open(name)
  pre=np.asarray(img)
  original_dims=pre.shape
  data=pre_data.flatten()
  np.savetxt('myfile.csv', data)
  return original_dims

# %%
dims=image_to_csv('avril.jpg')

# %%
dims
# Out:
# (549, 976, 3)

# %%
##Process the data

##KRISHNA PART

##fetching it back

proper=np.genfromtxt('myfile.csv')

# %%
plt.imshow(proper.reshape(dims)/255)
